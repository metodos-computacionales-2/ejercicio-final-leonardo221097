# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
# %%bash
# g++ pendulum.cpp
# ./a.out 100000 > data.txt

# %%
a = np.loadtxt("data.txt")
t = a[:,0]
theta = a[:,1]
omega = a[:,2]
plt.plot(t[:100],theta[:100])
plt.savefig ('angulovstheta.png')
